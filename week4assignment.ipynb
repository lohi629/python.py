# %% [markdown]
# <a href="https://colab.research.google.com/github/lohi629/python.py/blob/main/week4assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train=pd.read_csv('/content/drive/MyDrive/Classroom/dataset/train_data.csv')
test=pd.read_csv('/content/drive/MyDrive/Classroom/dataset/test_data.csv')
sample_submission=pd.read_csv('/content/drive/MyDrive/Classroom/dataset/sample_submission.csv')
train.head()
#test.head()
# Out:
#    id  battery_power  bluetooth  clock_speed  dual_sim  fc  four_g  \
# 0   1            807          1          0.5         1   0       0
# 1   2           1065          1          0.5         0   0       1
# 2   3           1171          1          1.7         1   2       0
# 3   4            609          1          3.0         0  15       1
# 4   5           1193          1          2.3         0   7       0
#
#    int_memory  m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0          37    0.2        127  ...        245       829  2319     5     4
# 1          14    0.7         89  ...        188       928  3078    10     1
# 2          19    0.3        167  ...        248       755   263     6     5
# 3          44    0.3        117  ...         58      1253  2581    15    11
# 4          20    1.0        158  ...       1442      1904  1958     7     5
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
test.head()
# Out:
#      id  battery_power  bluetooth  clock_speed  dual_sim  fc  four_g  \
# 0  1401           1572          1          0.8         1   7       1
# 1  1402            707          0          2.1         1   2       0
# 2  1403            983          0          0.6         1   0       1
# 3  1404            827          1          0.6         1   9       1
# 4  1405           1975          1          1.9         1   2       0
#
#    int_memory  m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  \
# 0           8    0.8        169  ...   8        577      1237  3461     6
# 1          25    0.8        131  ...  17        495       574  3838     9
# 2          45    0.1        130  ...  11        948      1205  2052     5
# 3          35    0.2         87  ...  17         23       826  2367     5
# 4          31    0.9        151  ...  17        775      1607  3022    13
#
#    sc_w  talk_time  three_g  touch_screen  wifi
# 0     3         10        1             1     1
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1400 non-null   int64
#  1   battery_power  1400 non-null   int64
#  2   bluetooth      1400 non-null   int64
#  3   clock_speed    1400 non-null   float64
#  4   dual_sim       1400 non-null   int64
#  5   fc             1400 non-null   int64
#  6   four_g         1400 non-null   int64
#  7   int_memory     1400 non-null   int64
#  8   m_dep          1400 non-null   float64
#  9   mobile_wt      1400 non-null   int64
#  10  n_cores        1400 non-null   int64
#  11  pc             1400 non-null   int64
#  12  px_height      1400 non-null   int64
#  13  px_width       1400 non-null   int64
#  14  ram            1400 non-null   int64
#  15  sc_h           1400 non-null   int64
#  16  sc_w           1400 non-null   int64
#  17  talk_time      1400 non-null   int64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             600 non-null    int64
#  1   battery_power  600 non-null    int64
#  2   bluetooth      600 non-null    int64
#  3   clock_speed    600 non-null    float64
#  4   dual_sim       600 non-null    int64
#  5   fc             600 non-null    int64
#  6   four_g         600 non-null    int64
#  7   int_memory     600 non-null    int64
#  8   m_dep          600 non-null    float64
#  9   mobile_wt      600 non-null    int64
#  10  n_cores        600 non-null    int64
#  11  pc             600 non-null    int64
#  12  px_height      600 non-null    int64
#  13  px_width       600 non-null    int64
#  14  ram            600 non-null    int64
#  15  sc_h           600 non-null    int64
#  16  sc_w           600 non-null    int64
#  17  talk_time      600 non-null    int64
# ...

# %%
train.describe()
# Out:
#               id  battery_power    bluetooth  clock_speed     dual_sim  \
# count  1400.0000    1400.000000  1400.000000  1400.000000  1400.000000
# mean    700.5000    1237.027143     0.499286     1.526071     0.505714
# std     404.2895     440.555073     0.500178     0.824300     0.500146
# min       1.0000     502.000000     0.000000     0.500000     0.000000
# 25%     350.7500     842.000000     0.000000     0.700000     0.000000
# 50%     700.5000    1222.500000     0.000000     1.500000     1.000000
# 75%    1050.2500    1615.000000     1.000000     2.300000     1.000000
# max    1400.0000    1998.000000     1.000000     3.000000     1.000000
#
#                 fc       four_g   int_memory        m_dep    mobile_wt  ...  \
# count  1400.000000  1400.000000  1400.000000  1400.000000  1400.000000  ...
# mean      4.215000     0.515714    32.147143     0.505143   140.125714  ...
# std       4.251417     0.499932    18.209559     0.290107    35.361221  ...
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(train.corr())
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.barplot(x= 'price_range',y='battery_power', data=train)
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.barplot(x= 'price_range', y='px_height', data=train, palette = 'Reds')
plt.subplot(1,2,2)
sns.barplot(x= 'price_range', y='px_width', data=train, palette = 'Blues')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='price_range', y='ram',data=train)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(train['three_g'],hue=train['price_range'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12,6))
sns.countplot(train['four_g'],hue=train['price_range'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x=train.drop(['price_range'],axis=1)
y=train['price_range']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier as kf
knn=kf(n_neighbors=21)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
# Out:
# 0.926530612244898

# %%
predictions=knn.predict(x_test)
print(predictions)
# Out:
# [0 2 2 1 3 3 1 2 0 0 0 1 2 0 3 0 0 3 1 3 2 2 3 0 1 3 1 3 1 1 0 3 2 3 1 1 1
#  1 0 3 2 3 2 1 3 2 2 2 1 2 1 0 1 1 3 2 0 0 2 0 2 1 3 2 1 1 0 1 1 2 1 2 1 1
#  1 1 0 3 2 0 2 3 1 0 2 3 1 2 2 3 3 3 2 2 2 0 1 2 1 0 1 1 0 2 3 2 3 2 2 1 1
#  1 3 0 0 0 3 3 3 1 2 0 0 3 2 1 3 1 1 2 1 3 0 3 0 0 2 3 3 2 3 3 3 3 1 0 1 2
#  2 0 2 0 2 1 0 3 0 1 3 3 0 2 3 2 1 3 3 3 3 2 0 2 0 1 1 0 0 3 2 1 0 2 2 2 3
#  2 2 0 1 0 0 0 1 0 0 3 1 2 0 1 1 2 0 1 1 1 3 3 0 2 0 0 1 0 2 3 3 1 3 3 0 3
#  1 3 3 3 2 1 3 3 0 1 3 2 0 3 1 1 2 1 1 1 1 1 1 3 3 0 0 0 0 0 0 3 1 1 0 3 2
#  3 3 2 2 0 3 0 1 3 2 2 0 3 2 2 3 2 2 3 3 0 3 0 1 0 3 3 1 3 3 1 0 2 1 0 1 1
#  2 3 1 3 0 1 0 1 2 3 2 2 2 2 2 0 0 1 0 2 3 3 0 2 0 1 1 3 1 2 3 1 1 2 0 1 0
#  0 3 0 1 1 3 2 3 1 0 0 2 0 1 2 1 0 2 2 1 1 3 1 3 2 1 3 2 0 3 3 1 2 2 0 1 2
#  0 1 2 0 3 0 0 2 1 2 3 0 0 3 3 0 2 1 1 2 2 1 0 1 3 1 1 1 0 0 3 2 0 1 2 0 2
#  0 0 0 0 3 2 2 0 0 0 1 0 3]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predictions)
# Out:
# 0.8761904761904762

# %%
test_pred=knn.predict(test)
print(test_pred)
# Out:
# [3 3 1 1 3 2 0 0 2 3 1 1 0 1 0 1 3 1 3 2 3 2 1 0 3 2 1 3 2 3 2 3 0 1 1 2 2
#  1 1 2 3 1 2 3 0 2 2 3 2 3 1 0 0 2 0 2 1 2 2 3 3 1 1 2 2 2 2 2 0 0 0 0 0 3
#  3 0 1 1 0 2 1 2 1 3 0 2 0 2 3 2 1 2 0 3 3 3 3 3 0 0 1 0 1 1 1 3 1 3 3 2 1
#  1 0 2 1 3 1 0 3 1 2 1 1 0 1 1 1 3 0 0 3 2 0 0 0 0 1 1 1 2 2 0 2 0 3 2 0 3
#  2 0 3 1 2 3 1 1 0 3 1 1 3 1 0 3 0 0 3 1 1 2 3 2 0 1 1 2 0 1 2 1 2 1 1 3 2
#  2 0 3 3 1 0 2 2 0 3 2 0 1 3 3 0 2 1 3 3 0 2 3 0 2 3 0 2 3 1 2 3 1 2 2 3 0
#  2 2 1 1 2 3 0 2 1 0 2 2 3 1 3 0 1 3 2 2 0 1 3 0 1 2 3 0 3 0 2 0 2 3 3 1 1
#  3 1 0 2 0 3 2 2 2 2 2 1 3 3 1 0 3 0 2 1 2 3 2 1 3 3 1 1 2 2 2 1 1 1 2 1 0
#  1 0 0 0 2 3 1 3 1 2 3 0 1 3 0 0 0 3 1 1 2 2 2 1 3 1 2 2 1 0 1 1 3 3 2 0 2
#  0 3 0 3 0 3 1 1 3 3 2 2 0 3 1 1 2 0 1 1 3 1 0 0 3 2 3 3 0 2 2 0 0 3 3 1 2
#  3 2 3 2 3 2 1 0 3 1 0 0 3 0 0 0 2 1 3 0 2 1 1 1 2 0 1 1 1 1 2 0 1 1 0 0 0
#  2 0 1 2 1 2 3 3 3 2 2 2 0 1 1 1 2 0 2 0 0 2 0 0 0 0 2 1 3 3 1 0 3 0 2 1 1
# ...

# %%
test['pricerange']=test_pred
test.head(10)
# Out:
#      id  battery_power  bluetooth  clock_speed  dual_sim  fc  four_g  \
# 0  1401           1572          1          0.8         1   7       1
# 1  1402            707          0          2.1         1   2       0
# 2  1403            983          0          0.6         1   0       1
# 3  1404            827          1          0.6         1   9       1
# 4  1405           1975          1          1.9         1   2       0
# 5  1406           1517          0          2.5         0   2       1
# 6  1407           1249          1          0.5         0   3       1
# 7  1408           1165          1          2.4         0  11       0
# 8  1409           1828          1          2.1         1   0       0
# 9  1410           1987          1          0.5         0   3       1
#
#    int_memory  m_dep  mobile_wt  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0           8    0.8        169  ...        577      1237  3461     6     3
# ...

# %%
result=pd.DataFrame(test)
print(result)
# Out:
#        id  battery_power  bluetooth  clock_speed  dual_sim  fc  four_g  \
# 0    1401           1572          1          0.8         1   7       1
# 1    1402            707          0          2.1         1   2       0
# 2    1403            983          0          0.6         1   0       1
# 3    1404            827          1          0.6         1   9       1
# 4    1405           1975          1          1.9         1   2       0
# ..    ...            ...        ...          ...       ...  ..     ...
# 595  1996            707          0          0.5         0   0       1
# 596  1997            888          0          2.6         1   2       1
# 597  1998           1130          0          1.8         1   0       0
# 598  1999            837          0          2.4         1   1       0
# 599  2000           1866          0          1.4         0   0       0
#
#      int_memory  m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  \
# ...

# %%
test={'id':sample_submission['id'],'price_range':test_pred}
result=pd.DataFrame(test)
result.to_csv('result.csv',index=False)
output=pd.read_csv('result.csv')
print(output)
# Out:
#        id  price_range
# 0    1401            3
# 1    1402            3
# 2    1403            1
# 3    1404            1
# 4    1405            3
# ..    ...          ...
# 595  1996            1
# 596  1997            3
# 597  1998            0
# 598  1999            0
# 599  2000            3
#
# [600 rows x 2 columns]
